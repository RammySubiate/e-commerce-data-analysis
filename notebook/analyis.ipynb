# %% [markdown]
# # E-commerce Business Transaction Data Analysis
# Data source: https://www.kaggle.com/datasets/gabrielramos87/an-online-shop-business

# %% [markdown]
# ### Step 1: Setting up the environment

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2: Loading and Inspecting the Data

# %%
file = "/Users/ramilojr.subiate/Documents/FILES/etl-to-dashboard/kaggle_data/sales_transaction.csv"
df = pd.read_csv(file)

# %%
df.head()
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2        581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3        581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
# 4        581475  12/9/2019     23239    Set Of 4 Knick Knack Tins Poppies
#
#    Price  Quantity  CustomerNo         Country
# 0  21.47        12     17490.0  United Kingdom
# 1  10.65        36     13069.0  United Kingdom
# 2  11.53        12     13069.0  United Kingdom
# 3  10.65        12     13069.0  United Kingdom
# 4  11.94         6     13069.0  United Kingdom

# %%
df.shape
# Out:
# (536350, 8)

# %%
df.columns
# Out:
# Index(['TransactionNo', 'Date', 'ProductNo', 'ProductName', 'Price',
#        'Quantity', 'CustomerNo', 'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536350 entries, 0 to 536349
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TransactionNo  536350 non-null  object
#  1   Date           536350 non-null  object
#  2   ProductNo      536350 non-null  object
#  3   ProductName    536350 non-null  object
#  4   Price          536350 non-null  float64
#  5   Quantity       536350 non-null  int64
#  6   CustomerNo     536295 non-null  float64
#  7   Country        536350 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.7+ MB

# %% [markdown]
# ### Step 3: Cleaning and Preparing the Data

# %% [markdown]
# 3.1 Renaming columns for clarity

# %%
df.rename(columns={
    "TransactionNo": "transaction_num",
    "Date": "date",
    "ProductNo": "product_num",
    "ProductName": "product_name",
    "Price": "price",
    "Quantity": "quantity",
    "CustomerNo": "customer_num",
    "Country": "country"
}, inplace=True)

df.columns
# Out:
# Index(['transaction_num', 'date', 'product_num', 'product_name', 'price',
#        'quantity', 'customer_num', 'country'],
#       dtype='object')

# %% [markdown]
# 3.2 Dropping duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(5200)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 3.3 Fixing Data types

# %%
df["date"] = pd.to_datetime(df["date"])
df["customer_num"] = df["customer_num"].astype("Int64").astype("str")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 531150 entries, 0 to 536349
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   transaction_num  531150 non-null  object
#  1   date             531150 non-null  datetime64[ns]
#  2   product_num      531150 non-null  object
#  3   product_name     531150 non-null  object
#  4   price            531150 non-null  float64
#  5   quantity         531150 non-null  int64
#  6   customer_num     531150 non-null  object
#  7   country          531150 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 36.5+ MB

# %% [markdown]
# 3.4 Handling Missing Values

# %%
df.isna().sum()
# Out:
# transaction_num    0
# date               0
# product_num        0
# product_name       0
# price              0
# quantity           0
# customer_num       0
# country            0
# dtype: int64

# %% [markdown]
# 3.5 Dropping cancelled orders

# %%
df.tail(30)
# Out:
#        transaction_num       date product_num  \
# 536320          536585 2018-12-01       37449
# 536321          536590 2018-12-01       22776
# 536322          536590 2018-12-01       22622
# 536323          536591 2018-12-01       37449
# 536324          536597 2018-12-01       22220
# 536325         C536383 2018-12-01      35004C
# 536326         C536391 2018-12-01       22556
# 536327         C536391 2018-12-01       21984
# 536328         C536391 2018-12-01       21983
# 536329         C536391 2018-12-01       21980
# 536330         C536391 2018-12-01       21484
# 536331         C536391 2018-12-01       22557
# 536332         C536391 2018-12-01       22553
# 536333         C536506 2018-12-01       22960
# 536334         C536543 2018-12-01       22632
# 536335         C536543 2018-12-01       22355
# 536336         C536548 2018-12-01       22244
# 536337         C536548 2018-12-01       22242
# 536338         C536548 2018-12-01       20914
# 536339         C536548 2018-12-01       22892
# 536340         C536548 2018-12-01       22654
# 536341         C536548 2018-12-01       22333
# 536342         C536548 2018-12-01       22245
# 536343         C536548 2018-12-01       22077
