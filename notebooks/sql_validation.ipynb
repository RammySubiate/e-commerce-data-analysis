# %% [markdown]
# ### Setting up the environment

# %%
from sqlalchemy import create_engine
import pandas as pd

# Connection parameters
PGHOST = "rammyserver.postgres.database.azure.com"
PGUSER = "rammysubiate"
PGPASSWORD = "data11212*" 
PGPORT = 5432
PGDATABASE = "postgres"

# Create engine
engine = create_engine(
    f"postgresql+psycopg2://{PGUSER}:{PGPASSWORD}@{PGHOST}:{PGPORT}/{PGDATABASE}"
)

# %% [markdown]
# ### Reusable SQL Query Function in Python

# %%
def run_query(query):
    """
    Executes a SQL query using the provided SQLAlchemy engine and returns a DataFrame.
    
    Parameters:
    - query (str): The SQL query to execute.
    - engine : SQLAlchemy engine connected to DB.
    
    Returns:
    - pd.DataFrame: Result of the query.
    """
    try:
        df = pd.read_sql(query, engine)
        return df
    except Exception as e:
        print(f"Error running query: {e}")
        return None

# %%
query = """

SELECT *
FROM fact_transactions
INNER JOIN dim_date
    USING(date_id)
INNER JOIN dim_product
    USING(product_id)
INNER JOIN dim_customer
    USING(customer_id)
LIMIT 5;
"""

df = run_query(query)
df
# Out:
#    customer_id  product_id  date_id  transaction_id  transaction_num  \
# 0         1296        5857      192               1           581482
# 1         3005        1209      192               2           581475
# 2         3005       18046      192               3           581475
# 3         3005        8297      192               4           581475
# 4         3005       11255      192               5           581475
#
#    quantity  revenue        date product_num  \
# 0        12   257.64  2019-12-09       22485
# 1        36   383.40  2019-12-09       22596
# 2        12   138.36  2019-12-09       23235
# 3        12   127.80  2019-12-09       23272
# 4         6    71.64  2019-12-09       23239
#
#                           product_name  price  customer_num         country  \
# 0        set of 2 wooden market crates  21.47         17490  United Kingdom
# 1  christmas star wish list chalkboard  10.65         13069  United Kingdom
# 2             storage tin vintage leaf  11.53         13069  United Kingdom
# 3    tree t-light holder willie winkie  10.65         13069  United Kingdom
# 4    set of 4 knick knack tins poppies  11.94         13069  United Kingdom
#
#   customer_frequency customer_contribution
# 0      more_frequent      most_contributor
# 1      most_frequent      most_contributor
# 2      most_frequent      most_contributor
# 3      most_frequent      most_contributor
# 4      most_frequent      most_contributor

# %% [markdown]
# ### Checking Column Names and Data Types

# %%
query = """
SELECT column_name, data_type
FROM INFORMATION_SCHEMA.COLUMNS
WHERE table_name IN (
        'fact_transactions',
        'dim_date', 
        'dim_product', 
        'dim_customer'
)
ORDER BY ordinal_position

"""
data_check = run_query(query)
data_check
# Out:
#               column_name          data_type
# 0                 date_id            integer
# 1          transaction_id            integer
# 2             customer_id            integer
# 3              product_id            integer
# 4                    date               date
# 5            customer_num            integer
# 6         transaction_num            integer
# 7             product_num  character varying
# 8            product_name  character varying
# 9                 date_id            integer
# 10                country  character varying
# 11                  price            numeric
# 12             product_id            integer
# 13            customer_id            integer
# 14               quantity            integer
# 15     customer_frequency  character varying
# 16                revenue            numeric
# 17  customer_contribution  character varying

# %% [markdown]
# ### Row Count

# %%
query = """

SELECT COUNT(*) AS row_count
FROM fact_transactions
INNER JOIN dim_date
    USING(date_id)
INNER JOIN dim_product
    USING(product_id)
INNER JOIN dim_customer
    USING(customer_id)


"""
row_count = run_query(query)
row_count
# Out:
#    row_count
# 0     522601

# %% [markdown]
# ### Checking for NULLs

# %%
query = """

SELECT COUNT(*) - COUNT(transaction_num) AS transaction_num_nulls,
    COUNT(*) - COUNT(product_num) AS product_num_nulls,
    COUNT(*) - COUNT(product_name) AS product_name_nulls,
    COUNT(*) - COUNT(price) AS price_nulls,
    COUNT(*) - COUNT(quantity) AS quantity_nulls
FROM fact_transactions
INNER JOIN dim_date
    USING(date_id)
INNER JOIN dim_product
    USING(product_id)
INNER JOIN dim_customer
    USING(customer_id)

"""

null_check = run_query(query)
null_check
# Out:
#    transaction_num_nulls  product_num_nulls  product_name_nulls  price_nulls  \
# 0                      0                  0                   0            0
#
#    quantity_nulls
# 0               0

# %% [markdown]
# ### Checking for Duplicates

# %%
columns = ["transaction_num","date","product_num","product_name","price",
           "quantity","revenue","customer_num","country", "customer_frequency", "customer_contribution"]

cols = (", ").join(columns)
query = f"""
WITH ranked AS (
    SELECT *,
        ROW_NUMBER() OVER(PARTITION BY {cols} ORDER BY date) AS rank
        FROM fact_transactions
        INNER JOIN dim_date
            USING(date_id)
        INNER JOIN dim_product
            USING(product_id)
        INNER JOIN dim_customer
            USING(customer_id)
)
SELECT COUNT(*) AS duplicate_count
FROM ranked
WHERE rank > 1;
"""

dup_check = run_query(query)
dup_check
# Out:
#    duplicate_count
# 0                0
